# %%
exemplo = 10000.51 #var exemplo = 10000.51;

# %%
print(exemplo) #Logger.log('o valor de exemplo é '+ exemplo)
# Out:
# efrem_ filho--- maranhão filho

# %%
exemplo = 'efrem'

# %%
exemplo = exemplo + 5 #diferente do GS
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-36-9ff467a19593> in <module>()
# ----> 1 exemplo = exemplo + 5 #diferente do GS
#
# TypeError: cannot concatenate 'str' and 'int' objects

# %%
exemplo = 'efrem_'

# %%
#Exemplo de condicional - https://www.w3schools.com/python/python_conditions.asp

if exemplo == 'efrem':
    exemplo = exemplo + " maranhão"
elif exemplo == 'efrem_':
    exemplo = exemplo + ' filho'
else:
    exemplo = exemplo + "-"
    if isinstance(exemplo, basestring):
        exemplo = exemplo + " maranhão filho"

"""
if(exemplo == 'efrem'){
  exemplo = exemplo + ' maranhao';
} else {
  exemplo = exemplo + "-";

if(parseInt(exemplo,10)) {
    exemplo = exemplo + ' silva';
  }
}
"""
# Out:
# '\nif(exemplo == \'efrem\'){\n  exemplo = exemplo + \' maranhao\';\n} else {\n  exemplo = exemplo + "-";\n  if(parseInt(exemplo,10)) {\n    exemplo = exemplo + \' silva\';\n  }\n}\n'

# %%
# Exemplo de loop - https://www.w3schools.com/python/python_for_loops.asp
efrems = ["efrem", "efrem_", "efrem+"]
for x in efrems:
  print(x)

for i in range(10,1000,6): 
    j = float(i)
    print(j/10)

"""
  for (var i = 1; i < 100; i = i + .6) {
    if (Math.floor(i) == Math.round(i)) {
      //Logger.log('o round é ' + Math.round(i) + ' e eu contei '+ i);
    } else {
      //Logger.log('o round é ' + Math.round(i) + ' e eu não contei o decimal' + i);
    }
  }
"""
# Out:
# efrem
# efrem_
# efrem+
# 1.0
# 1.6
# 2.2
# 2.8
# 3.4
# 4.0
# 4.6
# 5.2
# 5.8
# 6.4
# 7.0
# 7.6
# 8.2
# 8.8
# 9.4
# 10.0
# 10.6
# 11.2
# 11.8
# 12.4
# 13.0
# 13.6
# 14.2
# 14.8
# 15.4
# 16.0
# 16.6
# 17.2
# 17.8
# 18.4
# 19.0
# 19.6
# 20.2
# 20.8
# 21.4
# 22.0
# 22.6
# 23.2
# 23.8
# 24.4
# 25.0
# 25.6
# 26.2
# 26.8
# 27.4
# 28.0
# 28.6
# 29.2
# 29.8
# 30.4
# 31.0
# 31.6
# 32.2
# 32.8
# 33.4
# 34.0
# 34.6
# 35.2
# 35.8
# 36.4
# 37.0
# 37.6
# 38.2
# 38.8
# 39.4
# 40.0
# 40.6
# 41.2
# 41.8
# 42.4
# 43.0
# 43.6
# 44.2
# 44.8
# 45.4
# 46.0
# 46.6
# 47.2
# 47.8
# 48.4
# 49.0
# 49.6
# 50.2
# 50.8
# 51.4
# 52.0
# 52.6
# 53.2
# 53.8
# 54.4
# 55.0
# 55.6
# 56.2
# 56.8
# 57.4
# 58.0
# 58.6
# 59.2
# 59.8
# 60.4
# 61.0
# 61.6
# 62.2
# 62.8
# 63.4
# 64.0
# 64.6
# 65.2
# 65.8
# 66.4
# 67.0
# 67.6
# 68.2
# 68.8
# 69.4
# 70.0
# 70.6
# 71.2
# 71.8
# 72.4
# 73.0
# 73.6
# 74.2
# 74.8
# 75.4
# 76.0
# 76.6
# 77.2
# 77.8
# 78.4
# 79.0
# 79.6
# 80.2
# 80.8
# 81.4
# 82.0
# 82.6
# 83.2
# 83.8
# 84.4
# 85.0
# 85.6
# 86.2
# 86.8
# 87.4
# 88.0
# 88.6
# 89.2
# 89.8
# 90.4
# 91.0
# 91.6
# 92.2
# 92.8
# 93.4
# 94.0
# 94.6
# 95.2
# 95.8
# 96.4
# 97.0
# 97.6
# 98.2
# 98.8
# 99.4
# "\n  for (var i = 1; i < 100; i = i + .6) {\n    if (Math.floor(i) == Math.round(i)) {\n      //Logger.log('o round \xc3\xa9 ' + Math.round(i) + ' e eu contei '+ i);\n    } else {\n      //Logger.log('o round \xc3\xa9 ' + Math.round(i) + ' e eu n\xc3\xa3o contei o decimal' + i);\n    }\n  }\n"

# %%
import requests

# %%
# Exemplo API Externa - https://medium.com/quick-code/absolute-beginners-guide-to-slaying-apis-using-python-7b380dc82236 
# Para o Google Maps API - https://console.developers.google.com/apis/credentials?project=universidade-agora
request = requests.get('https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-7.136722,-34.845641&radius=20000&types=restaurant&key=AIzaSyCG828zfyvYvUx-FmMx6R_JRNLcH_9uvo0')
data = request.json()

for place in data['results']:
    print(place['vicinity'])
    
"""request = requests.get('https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-7.136722,-34.845641&radius=20000&types=restaurant&key=AIzaSyCG828zfyvYvUx-FmMx6R_JRNLcH_9uvo0')
data = request.json()

print(data)

for place in data:
    print(place)
request = requests.get('http://api.open-notify.org')
print(request.text)
"""

"""
  var url = 'https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-7.136722,-34.845641&radius=20000&types=restaurant&key=[YOUR-KEY]';
  var response = UrlFetchApp.fetch(url);
  var json = response.getContentText();
  var data = JSON.parse(json);
  
  //Logger.log(data.results.length);
  
  for(var a = 0; a<data.results.length; a++){
    //Logger.log(data.results[0].vicinity);
    Logger.log('O lugar se chama: '+data.results[a].name + 
    ' \ne tem coordenadas (latitude,longitude) em: '+ 
    data.results[a].geometry.location.lat+','+data.results[a].geometry.location.lng);
  }
"""
# Out:
# Rua Praia de Carapibus, 0 - Costa do Sol, João Pessoa
# Avenida Cabo Branco, 4350 - Cabo Branco, João Pessoa
# Rua Helena Meira Lima, 269 - Tambaú, João Pessoa
# Avenida Arthur Monteiro de Paiva, 1190 - Bessa, João Pessoa
# Avenida General Edson Ramalho, 696 - Manaíra, João Pessoa
# Rua Djalma Coelho, 20 - Bancários, João Pessoa
# Rua Lupércio Branco, 130 - Manaíra, João Pessoa
# Avenida Almirante Tamandaré, 512 - 512 - Tambaú, João Pessoa
# Rua Nossa Senhora dos Navegantes, 140 - Tambaú, João Pessoa
# Avenida Santa Júlia, 545 - Torre, João Pessoa
# Rua Bancário Sérgio Guerra, 39 - Bancários, João Pessoa
# Avenida Almirante Tamandaré, 310 - Tambaú, João Pessoa
# Rua Empresário João Rodrigues Alves, 466 - Bancários, João Pessoa
# Avenida Cruz das Armas, 1242 - Cruz das Armas, João Pessoa
# Av. Gal, Rua Geraldo Costa, 150 - Manaíra, João Pessoa
# Rua Marcionila da Conceição, 1259 - Cabo Branco, João Pessoa
# Rua Professora Leonor da Silva Coutinho, 36 - Mangabeira, João Pessoa
# Rua Conselheiro Henrique, 17 - Centro, João Pessoa
# Rua Rodrigues de Aquino, 49 - Centro, João Pessoa
# Avenida Senador Ruy Carneiro, 307 - Tambaú, João Pessoa
# "\n  var url = 'https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-7.136722,-34.845641&radius=20000&types=restaurant&key=[YOUR-KEY]';\n  var response = UrlFetchApp.fetch(url);\n  var json = response.getContentText();\n  var data = JSON.parse(json);\n  \n  //Logger.log(data.results.length);\n  \n  for(var a = 0; a<data.results.length; a++){\n    //Logger.log(data.results[0].vicinity);\n    Logger.log('O lugar se chama: '+data.results[a].name + \n    ' \ne tem coordenadas (latitude,longitude) em: '+ \n    data.results[a].geometry.location.lat+','+data.results[a].geometry.location.lng);\n  }\n"

# %%
import json

# %%
#parsed = json.loads(data)
print(json.dumps(data, indent=4, sort_keys=True))
# Out:
# {
#     "html_attributions": [],
#     "next_page_token": "CtQETAIAAL02cCZYrWt6F9lthYajUrQ5mO8GYDbG5s6V1yRbaLiHAYcZ3ZP07ux-OeLQ1-Nr96wl6JXXqfugeApLfvoWLti0x7Wd00cA1-rStcMxULKqplYyAHxeCpaTS7ROApH7oIOITAFQYjGPE8_7BFs310Q0nAFg3GA_BUkrD6foEuJMhxG2XiEeGHPB5lgyjNttY5w3ne4mlJ4j94Y_5r5catgbE0MZpw8j5pTLHQxoybShcH84udXR7wylrR3OzwHYbvlxx5fls1Ltc59GvXGqW0tZvlq79RcBlyj70DUqvunxaMZGbxLBd13Zq7QBaeBzjLciraGBJ85ozFLPQ2S7CRJiWuoQ7GMPdxK4t_KE44rcHOLn2un1jrmTCdhou016UuLDLFGm-dvmWZpqVCiapZUcFN7sdhCjTr_PMFz3EGkJNuAMov6yr0yyEnKB5HH7cQQuKi1IzRVjOaADdlRZfbBBqVKVm9aSpV0LH6J4bKnnR2z-UD3MBCc78XMofzVX96FeG20oDIEKMqynMb0u4pqruIXYKVyxZzHv0NfeBEQNXc5slfNNztToORFDN0EaOo8-xFcQulN_LrMx4-40jTegPmHZsITkmqZtL6QkuY8iRo2a-NecDE9NaO8v1ABraCLemYnsV_Gl6LwCNiHoxc6pvITYCigYyNTpH0WHqdq8QsQyUllzl7nYLp8yCZOb3luTio6JtI5TGMv-CJHATvLEvyPX82PbUhBHzcJ4iRfDnhboarHbsce7wF3I7kpzefb22IDaTNm8UtoyGY9LGdISEH7Ejku6oC1Xdb0mBE3Ap50aFEvadysgSSIyXjfRLbvUS0HxJR1l",
#     "results": [
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -7.181023400000001,
#                     "lng": -34.8146557
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -7.179674169708497,
#                         "lng": -34.8133196697085
#                     },
#                     "southwest": {
#                         "lat": -7.182372130291502,
#                         "lng": -34.8160176302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "ece85675aaed4ff719ef13f421ff54c6f50da2ce",
#             "name": "Zekas Pousada e Restaurante",
#             "photos": [
#                 {
#                     "height": 2448,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/106457684606457115143\">cleide targino</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA0eLB_kgwI66XZ8MrQUpPKIiG6ZxH1Zg0ADa0Ihvo0ayRyPrDLpIsj0kCE0TMm85RG9KVF9xb0Eei5hWSNLnRQzSmNhSH9yfPxksSnbmBwnwNhGOoPMcMtY6jLUhD69PoEhAKZE7NUTQmmbNym0R5C9MdGhQmpXXSXw-XM8LMuO-Z6qjN6iq_6g",
#                     "width": 3264
#                 }
#             ],
#             "place_id": "ChIJ3TZ3vbXDrAcRgM2bKII3edM",
#             "plus_code": {
#                 "compound_code": "R59P+H4 Jo\u00e3o Pessoa, State of Para\u00edba, Brazil",
#                 "global_code": "6947R59P+H4"
#             },
#             "rating": 4.2,
#             "reference": "ChIJ3TZ3vbXDrAcRgM2bKII3edM",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 41,
#             "vicinity": "Rua Praia de Carapibus, 0 - Costa do Sol, Jo\u00e3o Pessoa"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -7.1438181,
#                     "lng": -34.81295759999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -7.142434119708497,
#                         "lng": -34.8115805197085
#                     },
#                     "southwest": {
#                         "lat": -7.145132080291502,
#                         "lng": -34.8142784802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "6ce4d7d82989089fd56330e18e3fd04a0a4face5",
#             "name": "Hotel ibis Joao Pessoa",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 4912,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108015400946775312957\">Hotel ibis Joao Pessoa</a>"
#                     ],
#                     "photo_reference": "CmRaAAAANlYkBfpA6NHFUKSZYH1S4TDNdf7aXvJZlan6ebzftFK89YqIYLeHMWxhcKexuoEo4OAupfmhC3jj4Q8UpJQbnrkzJp0o9HkDgGOzqHV06JtspoJHAT8Zm17-IZ1j-afWEhB4hLjUxPDlU98-S_jGlxzjGhQmTlG6N4pEFvSl1y3kiuS6x2s_cw",
#                     "width": 5472
#                 }
#             ],
#             "place_id": "ChIJ_VgDgiHDrAcRactcvuuWFOU",
#             "plus_code": {
#                 "compound_code": "V54P+FR Cabo Branco, Jo\u00e3o Pessoa - State of Para\u00edba, Brazil",
#                 "global_code": "6947V54P+FR"
#             },
#             "rating": 4.3,
#             "reference": "ChIJ_VgDgiHDrAcRactcvuuWFOU",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1267,
#             "vicinity": "Avenida Cabo Branco, 4350 - Cabo Branco, Jo\u00e3o Pessoa"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -7.116126,
#                     "lng": -34.825503
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -7.114768169708499,
#                         "lng": -34.8241518697085
#                     },
#                     "southwest": {
#                         "lat": -7.117466130291503,
#                         "lng": -34.8268498302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "8d693ae4360af978e541a9cad2d1b726fae056c3",
#             "name": "Pousada do Caju City",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 379,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107176326465593635482\">Bruno Melo</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAY3Wld5HML0inVM-8L3LeYQpxkU58NLdq2-zwAusKoTl44khk9hJZXSh3DD2pcm8CSJHVi7RUaSfpC3ObWKNZksfFP3epE0PyvOwgaepFdCqeo39t41SPZntX7CfRtDPyEhATCnSzFkAFxGQ8bjlyse6XGhRRLwX86a-d09RVBezaf3qbKlSIcQ",
#                     "width": 673
#                 }
#             ],
#             "place_id": "ChIJH2EyvyXdrAcR95WK2rdneqI",
#             "plus_code": {
#                 "compound_code": "V5MF+GQ Jo\u00e3o Pessoa, State of Para\u00edba, Brazil",
#                 "global_code": "6947V5MF+GQ"
#             },
#             "rating": 3.7,
#             "reference": "ChIJH2EyvyXdrAcR95WK2rdneqI",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 23,
#             "vicinity": "Rua Helena Meira Lima, 269 - Tamba\u00fa, Jo\u00e3o Pessoa"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -7.065729799999999,
#                     "lng": -34.839793
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -7.064340269708498,
#                         "lng": -34.8383892697085
#                     },
#                     "southwest": {
#                         "lat": -7.067038230291502,
#                         "lng": -34.8410872302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/bar-71.png",
#             "id": "8086e9fe73852fc108e06fd08a1723d88fe1359d",
#             "name": "Bessa Grill",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1080,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/101057357229511422988\">Leonardo Leo</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAo8XPkSdpDIVvLDROUgpr1FvT9B5Zy2qvj9LlMzELMy4qa4IlVLAALNRVjPsoTtlCRKJjFwBZ1IJsNCnTBst3o4iYw50QYgOk8L2DmcvgQJCnOAEbUG1iS24736cT5rD0EhCNnQzko4fkJxwTMym9p1sSGhRJVHSSnu2mI3fC11Au1TDm18OBWA",
#                     "width": 1920
#                 }
#             ],
#             "place_id": "ChIJ9YDhD8LdrAcRMep6H5jQcLQ",
#             "plus_code": {
#                 "compound_code": "W5M6+P3 Bessa, Jo\u00e3o Pessoa - State of Para\u00edba, Brazil",
#                 "global_code": "6947W5M6+P3"
#             },
#             "price_level": 2,
#             "rating": 4.3,
#             "reference": "ChIJ9YDhD8LdrAcRMep6H5jQcLQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "bar",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 4566,
#             "vicinity": "Avenida Arthur Monteiro de Paiva, 1190 - Bessa, Jo\u00e3o Pessoa"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -7.103240500000001,
#                     "lng": -34.8319992
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -7.101944619708498,
#                         "lng": -34.8307356197085
#                     },
#                     "southwest": {
#                         "lat": -7.104642580291503,
#                         "lng": -34.8334335802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "c415666f15362a7dc420334d088fb73cd9347d3d",
#             "name": "Mangai Jo\u00e3o Pessoa",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3096,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/117912374303602259073\">Rodolfo Clavijo</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA_OeuzSxjC6v25LFWska6wNo1X68NjOb2XRl8i84rposLZ84epyr3kHr0-BThbV68L8sRGusvZip9cvvvq-xS9TjDLIRLLZwvVZjyu0jX7grWW72PUVPIWRbk806uKFbGEhC3K4nTSNsp5oi-znVsOasNGhS2dm_HMOZMLSyTequ5IQ4OHqIkzw",
#                     "width": 4128
#                 }
#             ],
#             "place_id": "ChIJQ3ocKRfdrAcRoTiNLHZAONo",
#             "plus_code": {
#                 "compound_code": "V5W9+P6 Mana\u00edra, Jo\u00e3o Pessoa - State of Para\u00edba, Brazil",
#                 "global_code": "6947V5W9+P6"
#             },
#             "price_level": 3,
#             "rating": 4.7,
#             "reference": "ChIJQ3ocKRfdrAcRoTiNLHZAONo",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 10786,
#             "vicinity": "Avenida General Edson Ramalho, 696 - Mana\u00edra, Jo\u00e3o Pessoa"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -7.145354099999999,
#                     "lng": -34.8480983
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -7.144072919708498,
#                         "lng": -34.8467768197085
#                     },
#                     "southwest": {
#                         "lat": -7.146770880291503,
#                         "lng": -34.8494747802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "092b178b63ff98c1d0295658a4472cca395f57f1",
#             "name": "Restaurante Coelho's",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3120,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/101576036497945390278\">Hugo Souto</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAqQIMcNIlBpUEWa9RozvX107P4PNH3S7jkmoXbWIMSBDgX3ZfQaYvi5xxETGXT53MjPNpUCPjLEfLsfY0UZI-xlGxzLzx9cQJsR-jKho5kUxlRw_WLUYg4M6UARwWeGQXEhBnTQKVGrgfOM2aMH-o1hWuGhT1IOjvkaVjWBx-0oy9QJgnRAuyzA",
#                     "width": 4160
#                 }
#             ],
#             "place_id": "ChIJT66N-ZbCrAcRLwkqHJ6ggFQ",
#             "plus_code": {
#                 "compound_code": "V532+VQ Jo\u00e3o Pessoa, State of Para\u00edba, Brazil",
#                 "global_code": "6947V532+VQ"
#             },
#             "price_level": 2,
#             "rating": 4.4,
#             "reference": "ChIJT66N-ZbCrAcRLwkqHJ6ggFQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "bar",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 2137,
#             "vicinity": "Rua Djalma Coelho, 20 - Banc\u00e1rios, Jo\u00e3o Pessoa"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -7.110620799999999,
#                     "lng": -34.8291774
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -7.109409069708497,
#                         "lng": -34.8277889697085
#                     },
#                     "southwest": {
#                         "lat": -7.112107030291502,
#                         "lng": -34.8304869302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "fb05792e8991d6c43a264ff351e4e29c991ddf42",
#             "name": "NAU Frutos do Mar",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 2592,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/112891190408896557751\">NAU Frutos do Mar</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA4ThcejlYXGc2F50pnWunIFkoKZNywP-UgX95TlZRPGgsoiqRll1ul96vJdB3-3vglBd9uWZzY2egZxa9XfEfQMLireUYZVoRWMSkA6bflBEiTkV7eUdCKIHT-nHOKBOOEhDg5ikmi_YGFUZZHVOa9w-UGhSpv0AvbE_KISeB3aUsIrvNzeKGAw",
#                     "width": 3872
#                 }
#             ],
#             "place_id": "ChIJe-c1LCPdrAcR5Z11M-uVoTM",
#             "plus_code": {
#                 "compound_code": "V5QC+Q8 Mana\u00edra, Jo\u00e3o Pessoa - State of Para\u00edba, Brazil",
#                 "global_code": "6947V5QC+Q8"
#             },
#             "price_level": 2,
#             "rating": 4.7,
#             "reference": "ChIJe-c1LCPdrAcR5Z11M-uVoTM",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 5876,
#             "vicinity": "Rua Lup\u00e9rcio Branco, 130 - Mana\u00edra, Jo\u00e3o Pessoa"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -7.114481,
#                     "lng": -34.8227555
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -7.113153119708499,
#                         "lng": -34.8213176197085
#                     },
#                     "southwest": {
#                         "lat": -7.115851080291503,
#                         "lng": -34.82401558029149
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "9fe64cbca48dd9bf9644f9c8cdf2780b40c923eb",
#             "name": "Bob's",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 1080,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/110919820315628675896\">Robson Alves</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA9dsdUyBBWOe6jCdK5HZksKEYl8lSpXyFaCjkdVC3PRapvlHo5GFB5QjC7OYfjjcdOLuPw4MUIv7XfdzOpV6lSYdNeqHsws9w-KKI-jzR0aDzTRFGxO9XpKATN3oOphGkEhBmcZ26zi9OwJ59CwdC4RUzGhTGzqVJRfxcwbbcmYXcLyYpcqwItQ",
#                     "width": 1920
#                 }
#             ],
#             "place_id": "ChIJ3zE5vybdrAcRlWXB6bNP-LU",
#             "plus_code": {
#                 "compound_code": "V5PG+6V Tamba\u00fa, Jo\u00e3o Pessoa - State of Para\u00edba, Brazil",
#                 "global_code": "6947V5PG+6V"
#             },
#             "price_level": 2,
#             "rating": 4.1,
#             "reference": "ChIJ3zE5vybdrAcRlWXB6bNP-LU",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 878,
#             "vicinity": "Avenida Almirante Tamandar\u00e9, 512 - 512 - Tamba\u00fa, Jo\u00e3o Pessoa"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -7.1138164,
#                     "lng": -34.82477229999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -7.112456669708497,
#                         "lng": -34.8233170197085
#                     },
#                     "southwest": {
#                         "lat": -7.115154630291502,
#                         "lng": -34.8260149802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "702ef351a3d9e1562c2a409f8f6773dc52074928",
#             "name": "Famiglia Muccini Italian Restaurant",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 315,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/100493305590444136254\">Famiglia Muccini</a>"
#                     ],
#                     "photo_reference": "CmRaAAAARrq01kYCEoqVgYi48HB0ZUqWR0pwBkJm4mLtfsJp9x0PQEHuSOeqTTX8z1nUbwMEAeoR8j4dC-A-1BkeEcmFiiQs3toY3MUnkAPlOrqL0vUhLJo_4HfV1f8HroRlKvVxEhCONzhzsRFaJjkxvzQqkygNGhTksv1S6hdvz9Kp3EO4S8l73fKTMQ",
#                     "width": 851
#                 }
#             ],
#             "place_id": "ChIJa4696yPdrAcR7EzrD7u74Xk",
#             "plus_code": {
#                 "compound_code": "V5PG+F3 Tamba\u00fa, Jo\u00e3o Pessoa - State of Para\u00edba, Brazil",
#                 "global_code": "6947V5PG+F3"
#             },
#             "price_level": 3,
#             "rating": 4.6,
#             "reference": "ChIJa4696yPdrAcR7EzrD7u74Xk",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1683,
#             "vicinity": "Rua Nossa Senhora dos Navegantes, 140 - Tamba\u00fa, Jo\u00e3o Pessoa"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -7.1245135,
#                     "lng": -34.86076420000001
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -7.123139919708498,
#                         "lng": -34.8594675197085
#                     },
#                     "southwest": {
#                         "lat": -7.125837880291503,
#                         "lng": -34.86216548029149
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "43d68e725cfe75ae49306014ccfcc01095804d00",
#             "name": "Picanha do Bastos",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1728,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/100736711815228484786\">Delosmar magalh\u00e3es</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAuRCUlv8peanYOna0fe9BkcdADNa48O_-K0DzLnjQtsPlNVdPfoDrtTXbXggksNsLqYVQucAb7qFIxFM4fd9Jc6Vmlg2W8spf2h9hwoyxgYgScoVH2_bBc6t_621JNP7WEhARWydjgG2D1JvONS_dB3svGhTRuPeZD_i9bXeF-y39yr0_j7unnw",
#                     "width": 2592
#                 }
#             ],
#             "place_id": "ChIJj9sdY6rCrAcRacEdhKfKwG0",
#             "plus_code": {
#                 "compound_code": "V4GQ+5M Torre, Jo\u00e3o Pessoa - State of Para\u00edba, Brazil",
#                 "global_code": "6947V4GQ+5M"
#             },
#             "price_level": 2,
#             "rating": 4.4,
#             "reference": "ChIJj9sdY6rCrAcRacEdhKfKwG0",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1804,
#             "vicinity": "Avenida Santa J\u00falia, 545 - Torre, Jo\u00e3o Pessoa"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -7.149622399999999,
#                     "lng": -34.84104689999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -7.148348719708498,
#                         "lng": -34.83976321970849
#                     },
#                     "southwest": {
#                         "lat": -7.151046680291502,
#                         "lng": -34.84246118029149
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "92e29f5b7e52a85f955b2bec76ccd9adffdfaf2a",
#             "name": "Boteco da Cerveja",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 4032,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/105518783090081940637\">Jo\u00e3o Felix</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAEOCoeZ2Ho3YNvtVV2nYijLwxb2wIOcaqwJAD1RslB_jeiXumQlhAlDbasCmse-WrPW9I0o6g8StcEKkVgM-HMWZpERKcE_pHmOHNMXp6Zh6p5HDoPqhSte9GR_20fHU7EhCP7cBKll9yWWpLxsz3S6epGhQCJnt1GoVEeIQZIJNGd60ScyMcrg",
#                     "width": 3024
#                 }
#             ],
#             "place_id": "ChIJdY2IPpPCrAcR5NlQvIXJO7k",
#             "plus_code": {
#                 "compound_code": "V525+5H Jo\u00e3o Pessoa, State of Para\u00edba, Brazil",
#                 "global_code": "6947V525+5H"
#             },
#             "price_level": 2,
#             "rating": 3.9,
#             "reference": "ChIJdY2IPpPCrAcR5NlQvIXJO7k",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "bar",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 324,
#             "vicinity": "Rua Banc\u00e1rio S\u00e9rgio Guerra, 39 - Banc\u00e1rios, Jo\u00e3o Pessoa"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -7.1127107,
#                     "lng": -34.8228249
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -7.111341769708498,
#                         "lng": -34.8213965697085
#                     },
#                     "southwest": {
#                         "lat": -7.114039730291502,
#                         "lng": -34.82409453029149
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "3e3ed34d012a5b2bab93152eb057b0dcf9450e56",
#             "name": "Palace Gourmet",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 720,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/100742847067231187467\">Sandra Costa</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAwtKcVKbz2Bwq23uxnl8ZWSvyyA__8BRjdrGXpWm4mMmEq2YGOeE0j_3GdSxIxZXNSb56x7Kxsau0UersZLTFJrv-YrSVr4bleWLUBggrBCrdR7tCcHFSKIXYrTQr1jRoEhCte_dU-5Rqy3hSbNYz0QlDGhRAujPXaVg1BKSGiY7pCMzW4r821g",
#                     "width": 1280
#                 }
#             ],
#             "place_id": "ChIJQRoeRCHdrAcRQiXdKO2MAcg",
#             "plus_code": {
#                 "compound_code": "V5PG+WV Tamba\u00fa, Jo\u00e3o Pessoa - State of Para\u00edba, Brazil",
#                 "global_code": "6947V5PG+WV"
#             },
#             "price_level": 2,
#             "rating": 4.1,
#             "reference": "ChIJQRoeRCHdrAcRQiXdKO2MAcg",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 393,
#             "vicinity": "Avenida Almirante Tamandar\u00e9, 310 - Tamba\u00fa, Jo\u00e3o Pessoa"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -7.147397000000001,
#                     "lng": -34.84631799999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -7.146008419708497,
#                         "lng": -34.84495516970851
#                     },
#                     "southwest": {
#                         "lat": -7.148706380291502,
#                         "lng": -34.8476531302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "aef5c629e8d81b641f28a0393658aba2b5cbaafc",
#             "name": "Cachorro Quente do Z\u00e9",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 500,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/103297435946330998579\">Cachorro Quente do Z\u00e9</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAzUNOGdTp2oJGFdIcjl9M7xvH2wUwVpq-TjDyL7DQd4Wt-1S7qKnycMGXqdkOCGeBmATxnnykFEbzXHIf0PoR7wU2JSec9RJD3x3fPBIe-iq-VO5IBh_B0Ygbo1yutlx2EhDJBBHDp7Xfel-HnEa2NWkVGhSRQAyP8lOZCYgk5jLTaqbs-1RTlg",
#                     "width": 1600
#                 }
#             ],
#             "place_id": "ChIJJUrLq5bCrAcRiNU3BoV2vDo",
#             "plus_code": {
#                 "compound_code": "V533+2F Banc\u00e1rios, Jo\u00e3o Pessoa - State of Para\u00edba, Brazil",
#                 "global_code": "6947V533+2F"
#             },
#             "price_level": 2,
#             "rating": 4.4,
#             "reference": "ChIJJUrLq5bCrAcRiNU3BoV2vDo",
#             "scope": "GOOGLE",
#             "types": [
#                 "meal_takeaway",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1370,
#             "vicinity": "Rua Empres\u00e1rio Jo\u00e3o Rodrigues Alves, 466 - Banc\u00e1rios, Jo\u00e3o Pessoa"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -7.142963,
#                     "lng": -34.890802
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -7.141642869708497,
#                         "lng": -34.8893930197085
#                     },
#                     "southwest": {
#                         "lat": -7.144340830291502,
#                         "lng": -34.8920909802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "6672ba1e4ae00c3439f0158bb17823c942963796",
#             "name": "Kell's Sorveteria e Pizzaria",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 2336,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/110895482556950910218\">jos\u00e9 henrique xavier filho</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAuiqYFOdznwtuTcarsGcpVv-RiaNpPWF5Xmtd3PNBtVAA7VJcLRnQrjUlLFYJZIgtVH5bggVd1uCWWFwdiXoDxhLQPvYofP9jJBRt5RJkP-6rtAbbLlU8EkArERKDD4pDEhAVUQY4JsHAfpV02I7sYfy9GhQj037i30cIAaKlai5BJGszlN1b4g",
#                     "width": 4160
#                 }
#             ],
#             "place_id": "ChIJJZZq70PorAcRWuUECTxo8JM",
#             "plus_code": {
#                 "compound_code": "V445+RM Cruz das Armas, Jo\u00e3o Pessoa - State of Para\u00edba, Brazil",
#                 "global_code": "6947V445+RM"
#             },
#             "price_level": 1,
#             "rating": 4.3,
#             "reference": "ChIJJZZq70PorAcRWuUECTxo8JM",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 379,
#             "vicinity": "Avenida Cruz das Armas, 1242 - Cruz das Armas, Jo\u00e3o Pessoa"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -7.1085018,
#                     "lng": -34.827488
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -7.107159569708497,
#                         "lng": -34.8260785197085
#                     },
#                     "southwest": {
#                         "lat": -7.109857530291502,
#                         "lng": -34.82877648029149
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "f9312e2aeff2ab1fdfd556f59d6379a4af7da7fd",
#             "name": "Salutte Restaurantes",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1536,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/113055200541527886973\">Salutte Restaurantes</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAOjlV-zE5A7xB4I_6u21IubVT3VMzsacJhLJb0AC42UJW8rUcrPc9QxpHoNazS5-B7CVBWALKUCZ15c1VezJF5_QugJ72bJbyYGE2dqMX7ljKm_CWuOIi7wmkYyW0YqHzEhD5g0hGzeYnMwxOHO1PuyLsGhSBUJ0vQihECLEOEPnDusIt_adbZg",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJY-0ouSLdrAcR_JPBZXDc4Q0",
#             "plus_code": {
#                 "compound_code": "V5RF+H2 Mana\u00edra, Jo\u00e3o Pessoa - State of Para\u00edba, Brazil",
#                 "global_code": "6947V5RF+H2"
#             },
#             "price_level": 2,
#             "rating": 4.5,
#             "reference": "ChIJY-0ouSLdrAcR_JPBZXDc4Q0",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 686,
#             "vicinity": "Av. Gal, Rua Geraldo Costa, 150 - Mana\u00edra, Jo\u00e3o Pessoa"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -7.1202371,
#                     "lng": -34.825623
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -7.118874419708498,
#                         "lng": -34.8243344197085
#                     },
#                     "southwest": {
#                         "lat": -7.121572380291503,
#                         "lng": -34.8270323802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "2409b793a2ae407a022d5f7bbb3ac56430f411a7",
#             "name": "Villa Trigueiro Restaurante",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 4032,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/111398554093750778249\">Aparecido Djalma da Silva</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAzzkkmZKZg5YFIF0ga0_mbGPlSlIni68eTEQLuuhVT1rOfvn1PVGCwC_An-KMPWwI0gW4h_NLPvDgKa0j8SXXTR__ilhHist1IEEhWGyEmDz2VQCNZ_h0SjTOGU1NkzgGEhBmYygMMif_c1EpHTVQdV2mGhTlBjfvALLsNIXq_GJBzNnPeq195g",
#                     "width": 1960
#                 }
#             ],
#             "place_id": "ChIJH9hO4i7drAcRRsp5rQjeHZs",
#             "plus_code": {
#                 "compound_code": "V5HF+WQ Cabo Branco, Jo\u00e3o Pessoa - State of Para\u00edba, Brazil",
#                 "global_code": "6947V5HF+WQ"
#             },
#             "price_level": 2,
#             "rating": 4.3,
#             "reference": "ChIJH9hO4i7drAcRRsp5rQjeHZs",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 272,
#             "vicinity": "Rua Marcionila da Concei\u00e7\u00e3o, 1259 - Cabo Branco, Jo\u00e3o Pessoa"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -7.162407699999998,
#                     "lng": -34.84168700000001
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -7.161058569708498,
#                         "lng": -34.84035101970849
#                     },
#                     "southwest": {
#                         "lat": -7.163756530291503,
#                         "lng": -34.84304898029149
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png",
#             "id": "45915b4868f63998722c75110075472fe93bf9cc",
#             "name": "Tutti Aroma Pizzaria",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 600,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108668320033008512479\">Tutti Aroma Pizzaria</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA0qjcW7eyjYMqd_O7JeobWZHUSGuaB1GNuI5Ht06LpHZHs8EspUQRliIFuQZiJPllosSiTkj4QnP8iVKy6rWSoraxDeyHBjJjf_nWsHn3zU8HLOjc7U7Hvm8Ajg8kwYo8EhAILIcWbA1GUHYwQARbpKd3GhS1U8vgSx3z0Vgi5JfZJeXxkHCbxg",
#                     "width": 600
#                 }
#             ],
#             "place_id": "ChIJfU5JFmDCrAcRTgTDat3BrCk",
#             "plus_code": {
#                 "compound_code": "R5Q5+28 Mangabeira, Jo\u00e3o Pessoa - State of Para\u00edba, Brazil",
#                 "global_code": "6947R5Q5+28"
#             },
#             "rating": 4.4,
#             "reference": "ChIJfU5JFmDCrAcRTgTDat3BrCk",
#             "scope": "GOOGLE",
#             "types": [
#                 "meal_delivery",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 8,
#             "vicinity": "Rua Professora Leonor da Silva Coutinho, 36 - Mangabeira, Jo\u00e3o Pessoa"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -7.116118400000001,
#                     "lng": -34.8842288
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -7.114789819708497,
#                         "lng": -34.8828815197085
#                     },
#                     "southwest": {
#                         "lat": -7.117487780291501,
#                         "lng": -34.8855794802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "874b7cce28536459a7c89d59e726f45f56a03b2f",
#             "name": "Caf\u00e9 17",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3279,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/106375875456487191940\">Caf\u00e9 17</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA4swyCtvIsI5cSIB8Nv-MYyEgiLNx-KALXJpADVfLmZLLxrq7vt1WLLKhPgPbeaj_qxpkSAmP_Io3nfq4IXTz4TIt_5SNDqGZvAEVSXupZjZnzrpMSM8mfIjild35oKZvEhBrpqWw59T19qEiGgZ2I1SOGhRIQuZNKDviZ7cb38NGj-x-yL7-_w",
#                     "width": 4946
#                 }
#             ],
#             "place_id": "ChIJq1_1xhDdrAcRUDfwZ51j_6E",
#             "plus_code": {
#                 "compound_code": "V4M8+H8 Centro, Jo\u00e3o Pessoa - State of Para\u00edba, Brazil",
#                 "global_code": "6947V4M8+H8"
#             },
#             "price_level": 2,
#             "rating": 4.5,
#             "reference": "ChIJq1_1xhDdrAcRUDfwZ51j_6E",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 327,
#             "vicinity": "Rua Conselheiro Henrique, 17 - Centro, Jo\u00e3o Pessoa"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -7.1225272,
#                     "lng": -34.8834371
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -7.121164419708498,
#                         "lng": -34.8821559697085
#                     },
#                     "southwest": {
#                         "lat": -7.123862380291502,
#                         "lng": -34.8848539302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "edef518e8bb6912e5f7e41ecb952895a3d8ef3c1",
#             "name": "Snap Grill",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3240,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/114631137185095479173\">Claudio Ferreira</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAp5TdfwWar-5D3fsfDGv3m1XV37mjXXeC2VVT595vfS73mnlJ8S2J9Tn6Ao6hoUcE79O2E5Atz8guGGXnlnRsUGS7FNzRuxtcqD5skgCyqaBdFL81narpwc5A_IdKYtEIEhAP5MgPJqK0IRvYL2p6u3P3GhTuIZt2qOzIPhz4YVoWKxbp-OWvXA",
#                     "width": 4320
#                 }
#             ],
#             "place_id": "ChIJqYcqSVHdrAcRYggpwjaaK-A",
#             "plus_code": {
#                 "compound_code": "V4G8+XJ Jo\u00e3o Pessoa, State of Para\u00edba, Brazil",
#                 "global_code": "6947V4G8+XJ"
#             },
#             "rating": 4.8,
#             "reference": "ChIJqYcqSVHdrAcRYggpwjaaK-A",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 6,
#             "vicinity": "Rua Rodrigues de Aquino, 49 - Centro, Jo\u00e3o Pessoa"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -7.111680799999999,
#                     "lng": -34.8269611
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -7.110282369708497,
#                         "lng": -34.82563761970849
#                     },
#                     "southwest": {
#                         "lat": -7.112980330291502,
#                         "lng": -34.82833558029149
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "d70ecb59f303405e1f770cc403b76eba3b63685b",
#             "name": "Casa de P\u00e3es Delicatessen",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1920,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/110387525739128998140\">Ritshelle Sabano</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAQq4Ohjn5Sy498IcVoVHPZR6SEiVwUKRKtprGM_UdGXh5NboPDUxNYOKX-DT6uRLsxpLdN5uzdEhY7qSPMyeTwCx6mKAgjVLiZP__jO9YB322RiLXm94KI8vu41hqanfgEhCgbszmgRbnBn284WdMzK5JGhSBuSYWOOIqcSmICDfekfxeKpTDLg",
#                     "width": 1080
#                 }
#             ],
#             "place_id": "ChIJ6SikpyPdrAcRzkXh6CtWU54",
#             "plus_code": {
#                 "compound_code": "V5QF+86 Tamba\u00fa, Jo\u00e3o Pessoa - State of Para\u00edba, Brazil",
#                 "global_code": "6947V5QF+86"
#             },
#             "price_level": 2,
#             "rating": 4.2,
#             "reference": "ChIJ6SikpyPdrAcRzkXh6CtWU54",
#             "scope": "GOOGLE",
#             "types": [
#                 "bakery",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 122,
#             "vicinity": "Avenida Senador Ruy Carneiro, 307 - Tamba\u00fa, Jo\u00e3o Pessoa"
#         }
#     ],
#     "status": "OK"
# }
